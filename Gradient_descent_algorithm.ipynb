# %% [markdown]
# <a href="https://colab.research.google.com/github/panhdjf/machine-learning/blob/main/Gradient_descent_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from __future__ import division, print_function, unicode_literals
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Cho ham so f(x) = x^2 + 5.sin(x) xac dinh min

# %%
def cost(x):
  return x **2 + 5*np.sin(x)

# %%
def grad(x):
  return 2*x + 5*np.cos(x)

# %%
def myGD1(anpha, x0):
  x = [x0]
  for i in range (100):
    x_new = x[-1] - anpha * grad(x[-1])
    if abs(grad(x_new)) < 1e-3:
      break
    x.append(x_new)
  return (x, i)

# %%
(x1, i1) = myGD1(0.1, -5)
(x2, i2) = myGD1(0.1, 5)

print("x1 = %f, cost = %f, after %d"%(x1[-1], cost(x1[-1]),i1))
print("x2 = %f, cost = %f, after %d"%(x2[-1], cost(x2[-1]),i2))
# Out:
# x1 = -1.110667, cost = -3.246394, after 11
# x2 = -1.110341, cost = -3.246394, after 29

# %%
x_value = np.arange(-6,6,0.1)
x_value
# Out:
# array([-6.00000000e+00, -5.90000000e+00, -5.80000000e+00, -5.70000000e+00,
#        -5.60000000e+00, -5.50000000e+00, -5.40000000e+00, -5.30000000e+00,
#        -5.20000000e+00, -5.10000000e+00, -5.00000000e+00, -4.90000000e+00,
#        -4.80000000e+00, -4.70000000e+00, -4.60000000e+00, -4.50000000e+00,
#        -4.40000000e+00, -4.30000000e+00, -4.20000000e+00, -4.10000000e+00,
#        -4.00000000e+00, -3.90000000e+00, -3.80000000e+00, -3.70000000e+00,
#        -3.60000000e+00, -3.50000000e+00, -3.40000000e+00, -3.30000000e+00,
#        -3.20000000e+00, -3.10000000e+00, -3.00000000e+00, -2.90000000e+00,
#        -2.80000000e+00, -2.70000000e+00, -2.60000000e+00, -2.50000000e+00,
#        -2.40000000e+00, -2.30000000e+00, -2.20000000e+00, -2.10000000e+00,
#        -2.00000000e+00, -1.90000000e+00, -1.80000000e+00, -1.70000000e+00,
#        -1.60000000e+00, -1.50000000e+00, -1.40000000e+00, -1.30000000e+00,
# ...

# %%
y_value = cost(x_value)
y_value
# Out:
# array([ 3.73970775e+01,  3.66793833e+01,  3.59630109e+01,  3.52434277e+01,
#         3.45163332e+01,  3.37777016e+01,  3.30238224e+01,  3.22513372e+01,
#         3.14572733e+01,  3.06390734e+01,  2.97946214e+01,  2.89222631e+01,
#         2.80208230e+01,  2.70896163e+01,  2.61284550e+01,  2.51376506e+01,
#         2.41180104e+01,  2.30708297e+01,  2.19978789e+01,  2.09013856e+01,
#         1.97840125e+01,  1.86488308e+01,  1.74992895e+01,  1.63391807e+01,
#         1.51726022e+01,  1.40039161e+01,  1.28377055e+01,  1.16787285e+01,
#         1.05318707e+01,  9.40209669e+00,  8.29439996e+00,  7.21375335e+00,
#         6.16505925e+00,  5.15310060e+00,  4.18249314e+00,  3.25763928e+00,
#         2.38268410e+00,  1.56147394e+00,  7.97517981e-01,  9.39531668e-02,
#        -5.46487134e-01, -1.12150044e+00, -1.62923815e+00, -2.06832405e+00,
#        -2.43786802e+00, -2.73747493e+00, -2.96724865e+00, -3.12779093e+00,
# ...

# %%
plt.plot(x_value, y_value)

# %%
np.random.seed(2)

# %%
X = np.random.randn(1000,1)
y = 4 + 3 * X + 0.2 * np.random.randn(1000,1)
# x.Shape = (1000,1)
# x.Shape[0] = 1000
# Tạo một numpy array với tất cả phẩn tử là phan tu dau
one = np.ones(X.shape[0], 1)
Xbar = np.concatenate((one, X), axis = 1)

# %%
np.random.randn(1000,1)
# Out:
# array([[-4.16757847e-01],
#        [-5.62668272e-02],
#        [-2.13619610e+00],
#        [ 1.64027081e+00],
#        [-1.79343559e+00],
#        [-8.41747366e-01],
#        [ 5.02881417e-01],
#        [-1.24528809e+00],
#        [-1.05795222e+00],
#        [-9.09007615e-01],
#        [ 5.51454045e-01],
#        [ 2.29220801e+00],
#        [ 4.15393930e-02],
#        [-1.11792545e+00],
#        [ 5.39058321e-01],
#        [-5.96159700e-01],
#        [-1.91304965e-02],
#        [ 1.17500122e+00],
#        [-7.47870949e-01],
#        [ 9.02525097e-03],
#        [-8.78107893e-01],
#        [-1.56434170e-01],
#        [ 2.56570452e-01],
#        [-9.88779049e-01],
#        [-3.38821966e-01],
#        [-2.36184031e-01],
#        [-6.37655012e-01],
#        [-1.18761229e+00],
#        [-1.42121723e+00],
#        [-1.53495196e-01],
#        [-2.69056960e-01],
#        [ 2.23136679e+00],
#        [-2.43476758e+00],
#        [ 1.12726505e-01],
#        [ 3.70444537e-01],
# ...
