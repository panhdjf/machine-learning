# %% [markdown]
# <a href="https://colab.research.google.com/github/panhdjf/machine-learning/blob/main/Yolov8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Out:
# /content/drive/MyDrive/Blind_Spot

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import shutil
shutil.rmtree("/content/drive/MyDrive/Blind_Spot/runs")

# %%
# !mkdir {HOME}/datasets
# %cd datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="YOxx79NT86lBoYAfaIbX")
# project = rf.workspace("phng-anh-nguyn").project("traffic_vehicle")
# dataset = project.version(1).download("yolov8")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOxx79NT86lBoYAfaIbX")
project = rf.workspace("phng-anh-nguyn").project("traffic_vehicle")
dataset = project.version(2).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=451028da35a1ca74d3fac260e2660f5c7f3dbd3bc931859497d068b959790618
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=800
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 77.1MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !mkdir Test

# %%
cd Test
# Out:
# /content/drive/MyDrive/Test

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7286, done.
# remote: Counting objects: 100% (890/890), done.
# remote: Compressing objects: 100% (519/519), done.
# remote: Total 7286 (delta 486), reused 675 (delta 368), pack-reused 6396
# Receiving objects: 100% (7286/7286), 5.65 MiB | 12.75 MiB/s, done.
# Resolving deltas: 100% (4840/4840), done.
# Updating files: 100% (292/292), done.

# %%
# %cd ultralytics
# Out:
# /content/drive/MyDrive/Test/ultralytics

# %%
# !ADD requirements.txt ./
# !pip install -r requirements.txt --no-deps -t python/lib/python3.6/site-packages/
# Out:
# /bin/bash: ADD: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 76.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 107.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 92.4 MB/s eta 0:00:00
# ...

# %%
! ADD requirements.txt ./
# Out:
# /bin/bash: ADD: command not found

# %%
# !pip install -e ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/Test/ultralytics/ultralytics
# ERROR: file:///content/drive/MyDrive/Test/ultralytics/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/Blind_Spot/ultralytics/yolov8s.pt data=/content/drive/MyDrive/Blind_Spot/datasets/traffic_vehicle-2/data.yaml epochs=100 imgsz=800
# Out:
# /bin/bash: yolo: command not found
