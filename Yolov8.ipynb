# %% [markdown]
# <a href="https://colab.research.google.com/github/panhdjf/machine-learning/blob/main/Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import shutil
shutil.rmtree("/content/datasets")

# %%
# !mkdir {HOME}/datasets
# %cd /datasets
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# [Errno 2] No such file or directory: '/datasets'
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOxx79NT86lBoYAfaIbX")
project = rf.workspace("phng-anh-nguyn").project("traffic_vehicle")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic_vehicle-1 in yolov8:: 100%|██████████| 38885/38885 [00:10<00:00, 3877.72it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=5 imgsz=800
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
